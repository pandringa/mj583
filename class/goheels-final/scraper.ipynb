# %%
import requests
import scrapy
import json
REQ_HEADERS={'user-agent': 'UNC MEJO 583'}
resp = requests.get("http://goheels.com/roster.aspx?path=mbball", headers=REQ_HEADERS)
sel = scrapy.Selector(text=resp.text)

# %%
def loadPlayer(player_id):
    res = requests.get("http://goheels.com/roster.aspx?rp_id="+player_id, headers=REQ_HEADERS)
    page = scrapy.Selector(text=res.text)
    info = page.css('.sidearm-roster-player-fields')
    headers = info.css('dt').xpath('string()').extract()
    data = info.css('dd').xpath('string()').extract()
    bio = dict(zip(headers, data))
    names = page.css('.sidearm-roster-player-name span::text').extract()
    bio['First Name'] = names[0]
    bio['Last Name'] = names[1]
    bio['Full Name'] = ' '.join(names)
    bio['Number'] = page.css('.sidearm-roster-player-jersey-number::text').extract_first()
    bio['Image'] = page.css('.sidearm-roster-player-image img::attr(src)').extract_first()
    bio['Bio'] = page.css('#sidearm-roster-player-bio .row').xpath('string()').extract_first()
    return bio

# %%
stats_key = { 'current_stats': 'Opponent', 'career_stats': 'Season', 'gamehigh_stats': 'Statistic' }
def loadStats(player_id):
    stats_response = requests.get("http://goheels.com/services/responsive-roster-bio.ashx?type=stats&path=mbball&year=2017&rp_id="+player_id, headers=REQ_HEADERS).json()
    stats = {}
    for table_name in stats_response.keys():
        # Skip if no stats table available
        if not stats_response[table_name]: continue
        
        table_stats = {}
        table = scrapy.Selector(text=stats_response[table_name])
        table_header_rows = table.css('thead tr')

        # Fix bottom table which has two levels of headers
        if len(table_header_rows) > 1:
            first_headers = table_header_rows[0].css('th')
            second_headers = table_header_rows[1].css('th').xpath('string()').extract()
            table_headers = []
            for header in first_headers:
                colspan = header.xpath('@colspan').extract_first()
                if colspan:
                    n = int(colspan)
                    old_header = header.xpath('string()').extract_first()
                    table_headers.extend( [old_header+' '+new_header for new_header in second_headers[:n]] )
                    del second_headers[:n]
                else:
                    table_headers.append( header.xpath('string()').extract_first() )
        else:
            table_headers = table_header_rows[0].css('th').xpath('string()').extract()

        # Fix '%' colums by adding context
        for i, header in enumerate(table_headers):
            if header == '%': 
                table_headers[i] = table_headers[i-1] + ' %'

        for row in table.css('tbody tr, tfoot tr'):
            row_numbers = row.css('td, th').xpath('string()').extract()
            row_stats = dict(zip(table_headers, row_numbers))
            table_stats[ row_stats[ stats_key[table_name] ] ] = row_stats

        stats[ table_name ] = table_stats
        
    return stats

# %%
table = sel.css('table')[0]
headers = table.css('th').xpath('string()').extract()
players = []
for href in table.xpath('//tr//td//a/@href').extract():
    if 'roster.aspx' in href:
        player_id = re.search('rp_id=(\d+)', href).group(1)
        bio = loadPlayer(player_id)
        bio['Stats'] = loadStats(player_id)
        players.append(bio)

# %%
players[0]
# Out:
#     '3-Point FGA': '11',
#     '3-Point PCT': '.182',
#     'AST': '49',
#     'AST/G': '1.2',
#     'AVG': '1.5',
#     'BLK': '2',
#     'FO': '1',
#     'Free-Throws FT': '25',
#     'Free-Throws FTA': '41',
#     'Free-Throws PCT': '.610',
#     'GP': '40',
#     'GS': '0',
#     'Minutes AVG': '7.7',
#     'Minutes MIN': '309',
#     'PF': '28',
#     'PTS': '61',
#     'Rebounds AVG': '1.4',
#     'Rebounds DEF': '49',
#     'Rebounds OFF': '6',
#     'Rebounds TOT': '55',
#     'STL': '21',
#     'Season': '2016-17',
#     'T/O': '42',
#     'Totals FG': '17',
#     'Totals FGA': '60',
#     'Totals PCT': '.283'},
#    '2017-18': {'3-Point FG': '0',
#     '3-Point FGA': '3',
#     '3-Point PCT': '.000',
#     'AST': '16',
#     'AST/G': '1.1',
#     'AVG': '1.2',
#     'BLK': '0',
#     'FO': '0',
#     'Free-Throws FT': '3',
#     'Free-Throws FTA': '4',
#     'Free-Throws PCT': '.750',
#     'GP': '14',
#     'GS': '0',
#     'Minutes AVG': '7.9',
#     'Minutes MIN': '110',
#     'PF': '14',
#     'PTS': '17',
#     'Rebounds AVG': '0.8',
#     'Rebounds DEF': '11',
#     'Rebounds OFF': '0',
#     'Rebounds TOT': '11',
#     'STL': '6',
#     'Season': '2017-18',
#     'T/O': '9',
#     'Totals FG': '7',
#     'Totals FGA': '23',
#     'Totals PCT': '.304'},
#    'Total': {'3-Point FG': '2',
#     '3-Point FGA': '14',
#     '3-Point PCT': '.143',
#     'AST': '65',
#     'AST/G': '1.2',
#     'AVG': '1.4',
#     'BLK': '2',
#     'FO': '1',
#     'Free-Throws FT': '28',
#     'Free-Throws FTA': '45',
#     'Free-Throws PCT': '.622',
#     'GP': '54',
#     'GS': '0',
#     'Minutes AVG': '7.8',
#     'Minutes MIN': '419',
#     'PF': '42',
#     'PTS': '78',
#     'Rebounds AVG': '1.2',
#     'Rebounds DEF': '60',
#     'Rebounds OFF': '6',
#     'Rebounds TOT': '66',
#     'STL': '27',
#     'Season': 'Total',
#     'T/O': '51',
#     'Totals FG': '24',
#     'Totals FGA': '83',
#     'Totals PCT': '.289'}},
#   'current_stats': {' Bucknell': {'3FG/A': '0-0',
#     '3FG/A %': '.000',
#     'AST': '1',
#     'AVG': '5.5',
#     'BLK': '0',
#     'DEF': '2',
#     'Date': '11/15/17',
#     'FGM/A': '1-2',
#     'FGM/A %': '.500',
#     'FTM/A': '0-0',
#     'FTM/A %': '.000',
#     'GS': '',
#     'MIN': '10',
#     'OFF': '0',
#     'Opponent': ' Bucknell',
#     'PF': '1',
#     'PTS': '2',
#     'STL': '0',
#     'T/O': '1',
#     'TOT': '2'},
#    ' Duke': {'3FG/A': '0-0',
#     '3FG/A %': '.000',
#     'AST': '0',
#     'AVG': '2.1',
#     'BLK': '0',
#     'DEF': '0',
#     'Date': '02/08/18',
#     'FGM/A': '0-1',
#     'FGM/A %': '.000',
#     'FTM/A': '0-0',
#     'FTM/A %': '.000',
#     'GS': '',
#     'MIN': '3',
#     'OFF': '0',
#     'Opponent': ' Duke',
#     'PF': '0',
#     'PTS': '0',
#     'STL': '0',
#     'T/O': '0',
#     'TOT': '0'},
#    ' Miami': {'3FG/A': '0-1',
#     '3FG/A %': '.000',
#     'AST': '0',
#     'AVG': '1.3',
#     'BLK': '0',
#     'DEF': '0',
#     'Date': '02/27/18',
#     'FGM/A': '0-1',
#     'FGM/A %': '.000',
#     'FTM/A': '0-0',
#     'FTM/A %': '.000',
#     'GS': '',
#     'MIN': '4',
#     'OFF': '0',
#     'Opponent': ' Miami',
#     'PF': '2',
#     'PTS': '0',
#     'STL': '1',
#     'T/O': '3',
#     'TOT': '0'},
#    ' Michigan': {'3FG/A': '0-0',
#     '3FG/A %': '.000',
#     'AST': '4',
#     'AVG': '2.4',
#     'BLK': '0',
#     'DEF': '1',
#     'Date': '11/29/17',
#     'FGM/A': '2-2',
#     'FGM/A %': '1.000',
#     'FTM/A': '0-0',
#     'FTM/A %': '.000',
#     'GS': '',
#     'MIN': '8',
#     'OFF': '0',
#     'Opponent': ' Michigan',
#     'PF': '0',
#     'PTS': '4',
#     'STL': '0',
#     'T/O': '1',
#     'TOT': '1'},
#    ' Northern Iowa': {'3FG/A': '0-0',
#     '3FG/A %': '.000',
#     'AST': '2',
#     'AVG': '9.0',
#     'BLK': '0',
#     'DEF': '0',
#     'Date': '11/10/17',
#     'FGM/A': '3-6',
#     'FGM/A %': '.500',
#     'FTM/A': '3-4',
#     'FTM/A %': '.750',
#     'GS': '',
#     'MIN': '18',
#     'OFF': '0',
#     'Opponent': ' Northern Iowa',
#     'PF': '2',
#     'PTS': '9',
#     'STL': '2',
#     'T/O': '1',
#     'TOT': '0'},
#    ' Notre Dame': {'3FG/A': '0-0',
#     '3FG/A %': '.000',
#     'AST': '0',
#     'AVG': '1.7',
#     'BLK': '0',
#     'DEF': '0',
#     'Date': '02/12/18',
#     'FGM/A': '0-0',
#     'FGM/A %': '.000',
#     'FTM/A': '0-0',
#     'FTM/A %': '.000',
#     'GS': '',
#     'MIN': '6',
#     'OFF': '0',
#     'Opponent': ' Notre Dame',
#     'PF': '3',
#     'PTS': '0',
#     'STL': '0',
#     'T/O': '0',
#     'TOT': '0'},
#    ' Total': {'3FG/A': '0-3',
#     '3FG/A %': '.000',
#     'AST': '16',
#     'AVG': '1.2',
#     'BLK': '0',
#     'DEF': '11',
#     'Date': '',
#     'FGM/A': '7-23',
#     'FGM/A %': '.304',
#     'FTM/A': '3-4',
#     'FTM/A %': '.750',
#     'GS': '',
#     'MIN': '110',
#     'OFF': '0',
#     'Opponent': ' Total',
#     'PF': '14',
#     'PTS': '17',
#     'STL': '6',
#     'T/O': '9',
#     'TOT': '11'},
#    'at Duke': {'3FG/A': '0-0',
#     '3FG/A %': '.000',
#     'AST': '0',
#     'AVG': '1.2',
#     'BLK': '0',
#     'DEF': '0',
#     'Date': '03/03/18',
#     'FGM/A': '0-1',
#     'FGM/A %': '.000',
#     'FTM/A': '0-0',
#     'FTM/A %': '.000',
#     'GS': '',
#     'MIN': '5',
#     'OFF': '0',
#     'Opponent': 'at Duke',
#     'PF': '1',
#     'PTS': '0',
#     'STL': '1',
#     'T/O': '0',
#     'TOT': '0'},
#    'at LOUISVILLE': {'3FG/A': '0-0',
#     '3FG/A %': '.000',
#     'AST': '2',
#     'AVG': '1.5',
#     'BLK': '0',
#     'DEF': '0',
#     'Date': '02/17/18',
#     'FGM/A': '0-0',
#     'FGM/A %': '.000',
#     'FTM/A': '0-0',
#     'FTM/A %': '.000',
#     'GS': '',
#     'MIN': '8',
#     'OFF': '0',
#     'Opponent': 'at LOUISVILLE',
#     'PF': '2',
#     'PTS': '0',
#     'STL': '0',
#     'T/O': '1',
#     'TOT': '0'},
#    'at North Carolina State': {'3FG/A': '0-0',
#     '3FG/A %': '.000',
#     'AST': '1',
#     'AVG': '1.9',
#     'BLK': '0',
#     'DEF': '0',
#     'Date': '02/10/18',
#     'FGM/A': '0-0',
#     'FGM/A %': '.000',
#     'FTM/A': '0-0',
#     'FTM/A %': '.000',
#     'GS': '',
#     'MIN': '4',
#     'OFF': '0',
#     'Opponent': 'at North Carolina State',
#     'PF': '0',
#     'PTS': '0',
#     'STL': '0',
#     'T/O': '0',
#     'TOT': '0'},
#    'at STANFORD': {'3FG/A': '0-1',
#     '3FG/A %': '.000',
#     'AST': '1',
#     'AVG': '4.3',
#     'BLK': '0',
#     'DEF': '2',
#     'Date': '11/20/17',
#     'FGM/A': '1-4',
#     'FGM/A %': '.250',
#     'FTM/A': '0-0',
#     'FTM/A %': '.000',
#     'GS': '',
#     'MIN': '12',
#     'OFF': '0',
#     'Opponent': 'at STANFORD',
#     'PF': '0',
#     'PTS': '2',
#     'STL': '1',
#     'T/O': '1',
#     'TOT': '2'},
#    'at Syracuse': {'3FG/A': '0-0',
#     '3FG/A %': '.000',
#     'AST': '1',
#     'AVG': '1.4',
#     'BLK': '0',
#     'DEF': '1',
#     'Date': '02/21/18',
#     'FGM/A': '0-0',
#     'FGM/A %': '.000',
#     'FTM/A': '0-0',
#     'FTM/A %': '.000',
#     'GS': '',
#     'MIN': '4',
#     'OFF': '0',
#     'Opponent': 'at Syracuse',
#     'PF': '1',
#     'PTS': '0',
#     'STL': '0',
#     'T/O': '0',
#     'TOT': '1'},
#    'vs Arkansas': {'3FG/A': '0-1',
#     '3FG/A %': '.000',
#     'AST': '1',
#     'AVG': '2.6',
#     'BLK': '0',
#     'DEF': '1',
#     'Date': '11/24/17',
#     'FGM/A': '0-2',
#     'FGM/A %': '.000',
#     'FTM/A': '0-0',
#     'FTM/A %': '.000',
#     'GS': '',
#     'MIN': '6',
#     'OFF': '0',
#     'Opponent': 'vs Arkansas',
#     'PF': '1',
#     'PTS': '0',
#     'STL': '0',
#     'T/O': '0',
#     'TOT': '1'},
#    'vs Michigan State': {'3FG/A': '0-0',
#     '3FG/A %': '.000',
#     'AST': '1',
#     'AVG': '2.2',
#     'BLK': '0',
#     'DEF': '0',
#     'Date': '11/26/17',
#     'FGM/A': '0-1',
#     'FGM/A %': '.000',
#     'FTM/A': '0-0',
#     'FTM/A %': '.000',
#     'GS': '',
#     'MIN': '8',
#     'OFF': '0',
#     'Opponent': 'vs Michigan State',
#     'PF': '0',
#     'PTS': '0',
#     'STL': '1',
#     'T/O': '1',
#     'TOT': '0'},
#    'vs Portland': {'3FG/A': '0-0',
#     '3FG/A %': '.000',
#     'AST': '2',
#     'AVG': '3.3',
#     'BLK': '0',
#     'DEF': '4',
#     'Date': '11/23/17',
#     'FGM/A': '0-3',
#     'FGM/A %': '.000',
#     'FTM/A': '0-0',
#     'FTM/A %': '.000',
#     'GS': '',
#     'MIN': '14',
#     'OFF': '0',
#     'Opponent': 'vs Portland',
#     'PF': '1',
#     'PTS': '0',
#     'STL': '0',
#     'T/O': '0',
#     'TOT': '4'}},
#   'gamehigh_stats': {'3-Point Field Goal Attempts': {'Opponent': 'vs. Miami',
#     'Statistic': '3-Point Field Goal Attempts',
#     'Value': '1'},
#    '3-Point Field Goals Made': {'Opponent': 'vs. Duke',
#     'Statistic': '3-Point Field Goals Made',
#     'Value': '0'},
#    'Assists': {'Opponent': 'vs. Michigan',
#     'Statistic': 'Assists',
#     'Value': '4'},
#    'Blocks': {'Opponent': 'vs. Duke', 'Statistic': 'Blocks', 'Value': '0'},
#    'Field Goal Attempts': {'Opponent': 'vs. Northern Iowa',
#     'Statistic': 'Field Goal Attempts',
#     'Value': '6'},
#    'Field Goals Made': {'Opponent': 'vs. Northern Iowa',
#     'Statistic': 'Field Goals Made',
#     'Value': '3'},
#    'Free Throw Attempts': {'Opponent': 'vs. Northern Iowa',
#     'Statistic': 'Free Throw Attempts',
#     'Value': '4'},
#    'Free Throws Made': {'Opponent': 'vs. Northern Iowa',
#     'Statistic': 'Free Throws Made',
#     'Value': '3'},
#    'Minutes': {'Opponent': 'vs. Northern Iowa',
#     'Statistic': 'Minutes',
#     'Value': '18'},
#    'Points': {'Opponent': 'vs. Northern Iowa',
#     'Statistic': 'Points',
#     'Value': '9'},
#    'Rebounds': {'Opponent': 'vs. Portland',
#     'Statistic': 'Rebounds',
#     'Value': '4'},
#    'Steals': {'Opponent': 'vs. Northern Iowa',
#     'Statistic': 'Steals',
#     'Value': '2'}}},
#  'Weight': '185'}

# %%
with open('heels_mbb.json', 'w') as jsonfile:
    json.dump(players, jsonfile)
